# %% [markdown]
# <img src='https://github.com/ClarisseAlvarenga/imersao-dados-desafio-final/blob/main/Imagens/pharmacology1.jpg?raw=true' width='100%'>

# %% [markdown]
# # **BUSCA DE COMPOSTOS FARMACOLÓGICOS COM MECANISMO DE AÇÃO INIBIDOR**
# ##**PROFILING E SWEETVIZ**

# %% [markdown]
# ## **PREPARAÇÃO DOS DADOS**

# %% [markdown]
# ### **Bases de Dados**

# %%
#Fontes de Dados
URL_experimentos = 'https://github.com/ClarisseAlvarenga/imersao-dados-desafio-final/blob/main/Dados/dados_experimentos.zip?raw=true'
URL_resultados = 'https://github.com/ClarisseAlvarenga/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true'

# %% [markdown]
# ### **Importando as Bibliotecas**

# %%
#AUTOML
#!pip install -U pandas-profiling
#!pip install sweetviz

# %%
#bibliotecas básicas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#AutoML
from pandas_profiling import ProfileReport
import sweetviz as sv

sns.set()

# %% [markdown]
# ### **Leitura das Bases de Dados**

# %%
#base de experimentos
experimentos = pd.read_csv(URL_experimentos, compression='zip')
#base de resultados
resultados = pd.read_csv(URL_resultados)

# %%
#alterando as colunas do dataset de experimentos, para que não conste o hífen no nome das colunas
experimentos.columns = experimentos.columns.str.replace('-','')

# %%
#separando apenas as colunas com MOA inibidores
inibidores = resultados.loc[:,resultados.columns.str.contains('inhibitor')]

# %%
colunas = ['id'] + list(inibidores.columns)
resultados_inibidores = resultados[colunas]

# %%
#somando os moas ativados pelos experimentos
contagem_linhas = resultados_inibidores.drop('id', axis=1).sum(axis=1)
resultados_inibidores['activated_inhibitors'] = contagem_linhas
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#incluindo a coluna gerada no nosso dataset de experimentos
experimentos = experimentos.merge(resultados_inibidores[['id','activated_inhibitors']], on='id')

# %%
experimentos['ativado'] = experimentos['activated_inhibitors'] != 0
experimentos.head()
# Out:
#              id tratamento  tempo  ...     c99 activated_inhibitors  ativado
# 0  id_000644bb2  com_droga     24  ...  0.4176                    1     True
# 1  id_000779bfc  com_droga     72  ...  0.7371                    0    False
# 2  id_000a6266a  com_droga     48  ...  0.6931                    3     True
# 3  id_0015fd391  com_droga     48  ... -0.8154                    0    False
# 4  id_001626bd3  com_droga     72  ...  0.7125                    0    False
#
# [5 rows x 879 columns]

# %%
#criando um relatório do pandas profiling - Comentado após a primeira rodada pelo tempo gasto na geração do relatório
relatorio_pandas = ProfileReport(experimentos, title='Pandas Profiling Experimentos', minimal=True)

# %%
relatorio_pandas.to_file("relatorio_pandas_experimentos.html")
# Out:
# Summarize dataset:   0%|          | 0/887 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Criando uma visualização com o Sweetviz usando o banco de dados completo - Comentado após a primeira rodada, pelo tempo gasto na geração do relatório
relatorio_sweetviz = sv.analyze(experimentos, target_feat='ativado', pairwise_analysis='off')
relatorio_sweetviz.show_html("relatorio_sweetviz_experimentos.html") # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report relatorio_sweetviz_experimentos.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
